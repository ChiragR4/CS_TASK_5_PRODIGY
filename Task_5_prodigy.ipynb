# %%
pip install scapy
# Out:
# Collecting scapy
#   Downloading scapy-2.5.0.tar.gz (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 8.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: scapy
#   Building wheel for scapy (setup.py) ... done
#   Created wheel for scapy: filename=scapy-2.5.0-py2.py3-none-any.whl size=1444327 sha256=fc12ab7faf8668d25accf61e55c7ddd153cae346acfc38a50d34dc819b252f43
#   Stored in directory: /root/.cache/pip/wheels/82/b7/03/8344d8cf6695624746311bc0d389e9d05535ca83c35f90241d
# Successfully built scapy
# Installing collected packages: scapy
# Successfully installed scapy-2.5.0

# %%
from scapy.all import *

# %%
def packet_analyzer(packet):
  if packet.haslayer(IP):
    sour_ip=packet[IP].src
    dest_ip=packet[IP].dst
    protocol = packet[IP].proto
    print(f"IP Packet: {sour_ip} --> {dest_ip} Protocol: {protocol}")

  if packet.haslayer(TCP):
    sour_port=packet[TCP].sport
    dest_port=packet[TCP].dport
    print(f"TCP Packet: {sour_port} --> {dest_port} Payload: {str(packet[TCP].payload)}")

  if packet.haslayer(UDP):
    sour_port=packet[UDP].sourceport
    dest_port=packet[UDP].sestport
    print(f"UDP Packet: {sour_port} --> {dest_port} Payload: {str(packet[UDP].payload)}")

sniff(prn=packet_analyzer, store=0)
# Out:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 37224 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 37224 Payload:
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 37224 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 37224 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 37224 --> 8080 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 37224 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 37224 Payload:
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 37224 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 37224 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 37224 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 37224 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 37224 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 37224 --> 8080 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 37224 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 37224 Payload:
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 37224 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 37224 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 37224 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 37224 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 37224 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 37224 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 37224 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 37224 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 37224 --> 8080 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 37224 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 37224 Payload:
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 37224 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 37224 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 37224 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 37224 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 37224 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 37224 --> 8080 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 37224 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 37224 Payload:
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 37224 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 37224 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 37224 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 37224 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 37224 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 37224 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 37224 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 37224 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 37224 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 37224 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 37224 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 37224 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 37224 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 37224 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 37224 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 37224 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 37224 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 37224 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 37224 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 37224 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 37224 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 37224 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 37224 --> 8080 Payload:
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 37224 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 37224 --> 8080 Payload:
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 37224 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 58250 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 58250 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 58250 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 58250 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 58250 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 58250 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 58250 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 58250 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 58250 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 58250 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 58250 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 58250 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 58250 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 58250 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 58250 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 58250 --> 8080 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 58250 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 58250 Payload:
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 58250 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 58250 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 58250 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 58250 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 58250 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 58250 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 58250 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 58250 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 36332 --> 6000 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 6000 --> 36332 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 36332 --> 6000 Payload:
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 6000 --> 36332 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 36332 --> 6000 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 58250 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 58250 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 58250 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 58250 --> 8080 Payload:
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 58250 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 58250 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 43804 --> 8080 Payload:
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 43804 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 43804 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 43804 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 43804 Payload:
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 43804 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 43804 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 43804 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 43804 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 43804 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 43804 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 43804 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 43804 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 43804 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 43804 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 43804 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 43804 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 43804 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 43804 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 43804 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 43804 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 43804 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 43804 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 43804 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 43804 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 43804 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 43804 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 43804 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 43804 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 43804 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 43804 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 43804 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 43804 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 43804 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 43804 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 43804 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 43804 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 43804 --> 8080 Payload: Raw
# <Sniffed: TCP:0 UDP:0 ICMP:0 Other:0>
